# %% [markdown]
# # **Project Name**    -   **Amazon Prime TV Shows and Movies**

# %% [markdown]
# ##### **Project Type**    - EDA
# ##### **Contribution**    - Individual
# ##### **Team Member 1 - Shobhith B N**
# ##### **Team Member 2 -**
# ##### **Team Member 3 -**
# ##### **Team Member 4 -**

# %% [markdown]
# # **Project Summary -**

# %% [markdown]
# Write the summary here within 500-600 words.

# %% [markdown]
# # **GitHub Link -**

# %% [markdown]
# Provide your GitHub Link here.

# %% [markdown]
# # **Problem Statement**

# %% [markdown]
# **Write Problem Statement Here.**

# %% [markdown]
# #### **Define Your Business Objective?**

# %% [markdown]
# Answer Here.

# %% [markdown]
# # **General Guidelines** : -

# %% [markdown]
# 1.   Well-structured, formatted, and commented code is required.
# 2.   Exception Handling, Production Grade Code & Deployment Ready Code will be a plus. Those students will be awarded some additional credits.
#
#      The additional credits will have advantages over other students during Star Student selection.
#
#              [ Note: - Deployment Ready Code is defined as, the whole .ipynb notebook should be executable in one go
#                        without a single error logged. ]
#
# 3.   Each and every logic should have proper comments.
# 4. You may add as many number of charts you want. Make Sure for each and every chart the following format should be answered.
#
#
# ```
# # Chart visualization code
# ```
#
#
# *   Why did you pick the specific chart?
# *   What is/are the insight(s) found from the chart?
# * Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.
#
# 5. You have to create at least 20 logical & meaningful charts having important insights.
#
#
# [ Hints : - Do the Vizualization in  a structured way while following "UBM" Rule.
#
# U - Univariate Analysis,
#
# B - Bivariate Analysis (Numerical - Categorical, Numerical - Numerical, Categorical - Categorical)
#
# M - Multivariate Analysis
#  ]

# %% [markdown]
# # ***Let's Begin !***

# %% [markdown]
# ## ***1. Know Your Data***

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ### Import Libraries

# %%
# Import Libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### Dataset Loading

# %%
# Load Dataset
titles = pd.read_csv('/content/drive/MyDrive/Almabetter EDA capstone project/titles.csv')
credits = pd.read_csv('/content/drive/MyDrive/Almabetter EDA capstone project/credits.csv')

# %% [markdown]
# ### Dataset First View

# %%
# Dataset First Look
print(titles.head())
print(credits.head())
# Out:
#         id                        title   type  \
# 0  ts20945            The Three Stooges   SHOW
# 1  tm19248                  The General  MOVIE
# 2  tm82253  The Best Years of Our Lives  MOVIE
# 3  tm83884              His Girl Friday  MOVIE
# 4  tm56584            In a Lonely Place  MOVIE
#
#                                          description  release_year  \
# 0  The Three Stooges were an American vaudeville ...          1934
# 1  During America’s Civil War, Union spies steal ...          1926
# 2  It's the hope that sustains the spirit of ever...          1946
# 3  Hildy, the journalist former wife of newspaper...          1940
# 4  An aspiring actress begins to suspect that her...          1950
#
#   age_certification  runtime  \
# 0             TV-PG       19
# 1               NaN       78
# 2               NaN      171
# 3               NaN       92
# 4               NaN       94
#
#                                               genres production_countries  \
# ...

# %% [markdown]
# ### Dataset Rows & Columns count

# %%
# Dataset Rows & Columns count
print("Titles DataFrame shape:", titles.shape)
print("Credits DataFrame shape:", credits.shape)
# Out:
# Titles DataFrame shape: (9871, 15)
# Credits DataFrame shape: (124235, 5)

# %% [markdown]
# ### Dataset Information

# %%
# Dataset Info
print("Titles DataFrame info:")
print(titles.info())
print("\nCredits DataFrame info:")
print(credits.info())
# Out:
# Titles DataFrame info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9871 entries, 0 to 9870
# Data columns (total 15 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   id                    9871 non-null   object
#  1   title                 9871 non-null   object
#  2   type                  9871 non-null   object
#  3   description           9752 non-null   object
#  4   release_year          9871 non-null   int64
#  5   age_certification     3384 non-null   object
#  6   runtime               9871 non-null   int64
#  7   genres                9871 non-null   object
#  8   production_countries  9871 non-null   object
#  9   seasons               1357 non-null   float64
#  10  imdb_id               9204 non-null   object
#  11  imdb_score            8850 non-null   float64
#  12  imdb_votes            8840 non-null   float64
#  13  tmdb_popularity       9324 non-null   float64
# ...

# %% [markdown]
# #### Duplicate Values

# %%
# Dataset Duplicate Value Count
print("Duplicate values in Titles DataFrame:", titles.duplicated().sum())
print("Duplicate values in Credits DataFrame:", credits.duplicated().sum())
# Out:
# Duplicate values in Titles DataFrame: 3
# Duplicate values in Credits DataFrame: 56

# %% [markdown]
# #### Missing Values/Null Values

# %%
# Missing Values/Null Values Count
print("Missing values in Titles DataFrame:")
print(titles.isnull().sum())
print("\nMissing values in Credits DataFrame:")
print(credits.isnull().sum())
# Out:
# Missing values in Titles DataFrame:
# id                         0
# title                      0
# type                       0
# description              119
# release_year               0
# age_certification       6487
# runtime                    0
# genres                     0
# production_countries       0
# seasons                 8514
# imdb_id                  667
# imdb_score              1021
# imdb_votes              1031
# tmdb_popularity          547
# tmdb_score              2082
# dtype: int64
#
# Missing values in Credits DataFrame:
# person_id        0
# id               0
# name             0
# character    16287
# role             0
# dtype: int64

# %%
# Visualizing the missing values
# Visualization using a heatmap - Titles DataFrame
plt.figure(figsize=(10, 6))
sns.heatmap(titles.isnull(), cmap='viridis', cbar=False)
plt.title('Missing Values Heatmap - Titles DataFrame')
plt.show()

# %%
# Visualization using a heatmap - Credits DataFrame
plt.figure(figsize=(10, 6))
sns.heatmap(credits.isnull(), cmap='viridis', cbar=False)
plt.title('Missing Values Heatmap - Credits DataFrame')
plt.show()

# %% [markdown]
# ### What did you know about your dataset?

# %% [markdown]
# Titles DataFrame:
#
# * It has 9871 rows and 15 columns.
# * It contains information about movies and shows, including their ID,
# title, type, description, release year, age certification, runtime, genres, production countries, number of seasons (for shows), IMDb ID, IMDb score, IMDb votes, TMDB popularity, and TMDB score.
# * There are missing values in the 'description', 'age_certification', 'seasons', 'imdb_id', 'imdb_score', 'imdb_votes', 'tmdb_popularity', and 'tmdb_score' columns.
# * There are 3 duplicate rows.
#
# Credits DataFrame:
#
# * It has 124235 rows and 5 columns.
# * It contains information about the cast and crew of the titles, including person ID, title ID, name, character, and role.
# * There are missing values in the 'character' column.
# * There are 56 duplicate rows.

# %% [markdown]
# ## ***2. Understanding Your Variables***

# %%
# Dataset Columns
print("Titles DataFrame columns:", titles.columns)
print("Credits DataFrame columns:", credits.columns)
# Out:
# Titles DataFrame columns: Index(['id', 'title', 'type', 'description', 'release_year',
#        'age_certification', 'runtime', 'genres', 'production_countries',
#        'seasons', 'imdb_id', 'imdb_score', 'imdb_votes', 'tmdb_popularity',
#        'tmdb_score'],
#       dtype='object')
# Credits DataFrame columns: Index(['person_id', 'id', 'name', 'character', 'role'], dtype='object')

# %%
# Dataset Describe
print("Titles DataFrame describe:")
print(titles.describe())
print("\nCredits DataFrame describe:")
print(credits.describe())
# Out:
# Titles DataFrame describe:
#        release_year      runtime      seasons   imdb_score    imdb_votes  \
# count   9871.000000  9871.000000  1357.000000  8850.000000  8.840000e+03
# mean    2001.327221    85.973052     2.791452     5.976395  8.533614e+03
# std       25.810071    33.512466     4.148958     1.343842  4.592015e+04
# min     1912.000000     1.000000     1.000000     1.100000  5.000000e+00
# 25%     1995.500000    65.000000     1.000000     5.100000  1.170000e+02
# 50%     2014.000000    89.000000     1.000000     6.100000  4.625000e+02
# 75%     2018.000000   102.000000     3.000000     6.900000  2.236250e+03
# max     2022.000000   549.000000    51.000000     9.900000  1.133692e+06
#
#        tmdb_popularity   tmdb_score
# count      9324.000000  7789.000000
# mean          6.910204     5.984247
# std          30.004098     1.517986
# min           0.000011     0.800000
# 25%           1.232000     5.100000
# 50%           2.536000     6.000000
# ...

# %% [markdown]
# Variables Description

# %% [markdown]
# Titles DataFrame:
#
# * id: Unique identifier for each title (movie or show).
# * title: The name of the movie or show.
# * type: Indicates whether the title is a 'MOVIE' or a 'SHOW'.
# * description: A brief summary or synopsis of the title.
# * release_year: The year the title was released.
# * age_certification: The age rating or certification for the title (e.g., TV-PG).
# * runtime: The duration of the title in minutes.
# * genres: A list of genres associated with the title.
# * production_countries: A list of countries where the title was produced.
# * seasons: The number of seasons for TV shows (NaN for movies).
# * imdb_id: The IMDb identifier for the title.
# * imdb_score: The IMDb rating for the title.
# * imdb_votes: The number of votes on IMDb for the title.
# * tmdb_popularity: The popularity score from The Movie Database (TMDB).
# * tmdb_score: The TMDB rating for the title.
#
# Credits DataFrame:
#
# * person_id: Unique identifier for each person (actor or director).
# * id: The title ID that the person is associated with.
# * name: The name of the person.
# * character: The character played by the person in the title (for actors).
# * role: The role of the person in the production (e.g., 'ACTOR' or 'DIRECTOR').

# %% [markdown]
# ### Check Unique Values for each variable.

# %%
# Check Unique Values for each variable.
print("Unique values in Titles DataFrame:")
print(titles.nunique())
print("\nUnique values in Credits DataFrame:")
print(credits.nunique())
# Out:
# Unique values in Titles DataFrame:
# id                      9868
# title                   9737
# type                       2
# description             9734
# release_year             110
# age_certification         11
# runtime                  207
# genres                  2028
# production_countries     497
# seasons                   32
# imdb_id                 9201
# imdb_score                86
# imdb_votes              3650
# tmdb_popularity         5325
# tmdb_score                89
# dtype: int64
#
# Unique values in Credits DataFrame:
# person_id    80508
# id            8861
# name         79758
# character    71097
# role             2
# dtype: int64

# %% [markdown]
# ## 3. ***Data Wrangling***

# %% [markdown]
# ### Data Wrangling Code

# %%
# Write your code to make your dataset analysis ready.

# Fill or drop missing values as appropriate
# Drop duplicate rows
titles.drop_duplicates(inplace=True)
credits.drop_duplicates(inplace=True)

# Handle missing values in titles DataFrame

# Fill missing 'description' values with a placeholder
titles['description'].fillna('No description available', inplace=True)

# Fill missing 'age_certification' values with 'Unrated'
titles['age_certification'].fillna('Unrated', inplace=True)

# For 'seasons', fill missing values with 0, assuming movies or shows with no seasons listed have 0 seasons
titles['seasons'].fillna(0, inplace=True)

# For IMDb and TMDB related columns, filling with the mean or median might not be appropriate as it could skew the data.
# For now, we will leave them as is or consider dropping rows/columns later if necessary for specific analyses.
# Dropping rows with missing imdb_id as it's a unique identifier
titles.dropna(subset=['imdb_id'], inplace=True)

# Display the number of remaining missing values after initial handling
print("Missing values in Titles DataFrame after handling:")
print(titles.isnull().sum())
print("\nMissing values in Credits DataFrame after handling:")
print(credits.isnull().sum())
# Out:
# Missing values in Titles DataFrame after handling:
# id                         0
# title                      0
# type                       0
# description                0
# release_year               0
# age_certification          0
# runtime                    0
# genres                     0
# production_countries       0
# seasons                    0
# imdb_id                    0
# imdb_score               354
# imdb_votes               364
# tmdb_popularity          544
# tmdb_score              1834
# dtype: int64
#
# Missing values in Credits DataFrame after handling:
# person_id        0
# id               0
# name             0
# character    16277
# role             0
# dtype: int64
# /tmp/ipython-input-14-728086735.py:11: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# ...

# %% [markdown]
# ### What all manipulations have you done and insights you found?

# %% [markdown]
# Answer Here.

# %% [markdown]
# **Manipulations Performed:**
#
# *   Dropped 3 duplicate rows from the `titles` DataFrame.
# *   Dropped 56 duplicate rows from the `credits` DataFrame.
# *   Filled missing values in the `description` column of the `titles` DataFrame with 'No description available'.
# *   Filled missing values in the `age_certification` column of the `titles` DataFrame with 'Unrated'.
# *   Filled missing values in the `seasons` column of the `titles` DataFrame with 0.
# *   Dropped rows with missing `imdb_id` values in the `titles` DataFrame.
#
# **Insights Gained:**
#
# *   After dropping rows with missing `imdb_id`, there are still missing values in `imdb_score`, `imdb_votes`, `tmdb_popularity`, and `tmdb_score` in the `titles` DataFrame. These will need to be addressed depending on the specific analysis being performed.
# *   There are still missing values in the `character` column of the `credits` DataFrame.

# %% [markdown]
# ## ***4. Data Vizualization, Storytelling & Experimenting with charts : Understand the relationships between variables***

# %% [markdown]
# ### What all manipulations have you done and insights you found?

# %% [markdown]
# Chart - 1: Visualize the distribution of movie and show types

# %%
# Chart - 1 visualization code

# Count the occurrences of each type
type_counts = titles['type'].value_counts()

# Create a bar plot
plt.figure(figsize=(8, 6))
type_counts.plot(kind='bar', color=['skyblue', 'salmon'])

# Add labels and title
plt.xlabel('Type')
plt.ylabel('Count')
plt.title('Distribution of Movies and Shows on Amazon Prime')
plt.xticks(rotation=0) # Keep labels horizontal
plt.tight_layout() # Adjust layout to prevent labels overlapping
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# To count the occurrences of each type, I created a bar plot to visualize the distribution.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# * We can see the distribution of movies and
# shows on Amazon Prime.
# * It clearly shows that there are significantly more movies than shows available on the platform.
# * This suggests that Amazon Prime's content library is heavily skewed towards movies.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# The insight that Amazon Prime has significantly more movies than shows can have both positive and potentially negative business impacts.
#
# * Positive Business Impact:
#
# Attracting movie lovers: A large movie library can be a strong attraction for users who primarily subscribe to streaming services for movies. This can help acquire and retain customers who are movie enthusiasts.
#
# * Negative Business Impact:
#
# Missing out on the popularity of TV shows: TV shows often create more sustained engagement and can lead to "binge-watching," which keeps subscribers active for longer periods. A relative lack of shows might mean missing out on this engagement and potentially losing subscribers who prefer TV series.

# %% [markdown]
# #### Chart - 2: Explore the distribution of runtime

# %%
# Chart - 2 visualization code
plt.figure(figsize=(12, 6))
sns.histplot(data=titles, x='runtime', hue='type', bins=50, kde=True, multiple="stack")
plt.title('Distribution of Runtime by Type')
plt.xlabel('Runtime (minutes)')
plt.ylabel('Number of Titles')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Created a histogram to visualize the distribution of runtime for movies and shows in the 'titles' DataFrame.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# * Shows that movies generally have a concentrated runtime between 70 and 120 minutes, with a peak around 90 minutes.
# * Shows, on the other hand, have a much shorter runtime, mostly below 60 minutes, representing individual episode lengths.
# * This highlights the fundamental difference in content format and viewing experience between movies and TV shows.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# * Positive Business Impact:
#
# Understanding the typical runtime of movies and shows allows Amazon Prime to tailor its content acquisition and production strategy. They can focus on acquiring movies within the preferred runtime range for their audience and developing shows with appropriate episode lengths for binge-watching.
# * Negative Growth Insights:
#
# While the insights themselves don't directly lead to negative growth, a failure to act on them could. For example:
#
# Ignoring Audience Preferences: If Amazon Prime were to heavily invest in movies with unusually long or short runtimes that don't align with audience preferences, it could lead to decreased viewership and engagement for those specific titles.

# %% [markdown]
# #### Chart - 3: Visualize the distribution of age certifications

# %%
# Chart - 3 visualization code
age_certification_counts = titles['age_certification'].value_counts()

plt.figure(figsize=(12, 6))
age_certification_counts.plot(kind='bar', color=sns.color_palette('viridis', len(age_certification_counts)))

plt.title('Distribution of Age Certifications')
plt.xlabel('Age Certification')
plt.ylabel('Number of Titles')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Count the occurrences of each unique value in the 'age_certification' column and created a bar plot to visualize these counts, adding appropriate labels and title for clarity.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# * The third chart, which visualizes the distribution of age certifications, shows the counts of titles for each age certification.
# * We can see which age ratings are most prevalent on Amazon Prime.
# * This information is crucial for understanding the target audience and content strategy of the platform.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Understanding the distribution of age certifications is very helpful for Amazon Prime and can lead to positive business impacts.
# * Positive Business Impact:
#
# Targeted Marketing: Knowing which age certifications are most common allows for more targeted marketing campaigns. For example, if there's a large amount of content rated G or PG, marketing can focus on attracting families. If there's a significant amount of TV-MA or R content, marketing can target adult audiences.
#
# * Negative Business Impact:
#
# Alienating Audiences: If the content is heavily skewed towards a few age certifications while neglecting others, it could alienate potential subscribers who are looking for content with different ratings. For example, a severe lack of family-friendly content could deter families from subscribing.

# %% [markdown]
# #### Chart - 4: Explore the distribution of imdb scores

# %%
# Chart - 4 visualization code
plt.figure(figsize=(10, 6))
sns.histplot(titles['imdb_score'], bins=30, kde=True)
plt.title('Distribution of IMDb Scores')
plt.xlabel('IMDb Score')
plt.ylabel('Number of Titles')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# I picked the histogram to visualize the distribution of IMDb scores because it is an effective way to show the frequency of different score ranges within the dataset. This helps us understand the typical IMDb ratings of titles on Amazon Prime and identify any peaks or patterns in the distribution.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Based on the histogram of IMDb scores, we can see that the majority of titles on Amazon Prime have an IMDb score between 6.0 and 8.0. There appears to be a peak around 7.0, indicating that a large number of titles fall within this above-average rating range. The distribution also shows fewer titles with very low or very high IMDb scores.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Understanding the distribution of IMDb scores can definitely help create a positive business impact for Amazon Prime.
#
# * Positive Business Impact:
#
# Benchmarking: The distribution serves as a benchmark to compare the quality of their content library against competitors or industry standards based on IMDb scores.
#
# * Negative Business Impact:
#
# Lack of High-Rated Content: If the platform has a significantly lower proportion of very highly-rated titles compared to competitors, it might be perceived as having a less premium or critically acclaimed library, potentially deterring some users.

# %% [markdown]
# #### Chart - 5: Analyze the distribution of tmdb scores

# %%
# Chart - 5 visualization code
plt.figure(figsize=(10, 6))
sns.histplot(titles['tmdb_score'], bins=30, kde=True)
plt.title('Distribution of TMDB Scores')
plt.xlabel('TMDB Score')
plt.ylabel('Number of Titles')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Created a histogram with KDE to visualize the distribution of TMDB scores.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Based on the histogram of TMDB scores, we can see that the distribution is quite similar to the IMDb scores. The majority of titles on Amazon Prime have a TMDB score between 5.0 and 8.0, with a notable peak around 6.0 to 7.0. Similar to IMDb scores, there are fewer titles with very low or very high TMDB scores. This suggests that the TMDB scores generally align with the IMDb scores in representing the perceived quality of the titles on the platform.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Understanding the distribution of TMDB scores can also help create a positive business impact for Amazon Prime, similar to the insights gained from IMDb scores.
#
# * Positive Business Impact:
#
# Alternative Quality Metric: TMDB scores provide an alternative or supplementary metric to IMDb scores for evaluating content quality. Having a similar distribution across both platforms suggests a general consistency in how titles are perceived by different rating communities. This can reinforce confidence in content evaluation.
#
# * Negative Business Impact:
#
# Consistency in Negative Perception: If both IMDb and TMDB scores show a similar pattern of a large number of low-scoring titles, it reinforces a potential negative perception of the overall content library quality.

# %% [markdown]
# #### Chart - 6: Visualize the relationship between runtime and imdb score

# %%
# Chart - 6 visualization code
plt.figure(figsize=(12, 8))
sns.scatterplot(data=titles, x='runtime', y='imdb_score', alpha=0.6)
plt.title('Runtime vs. IMDb Score')
plt.xlabel('Runtime (minutes)')
plt.ylabel('IMDb Score')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# To explore the relationship between two numerical variables, runtime and IMDb score, I chose a scatter plot. This chart helps visualize if there's a correlation or pattern between how long a title is and its user rating on IMDb.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Based on the scatter plot, there doesn't appear to be a strong linear correlation between runtime and IMDb score. While there's a general cluster of movies with runtimes between 60 and 120 minutes and IMDb scores between 5 and 8, there are titles with both high and low IMDb scores across various runtimes. This suggests that a longer or shorter runtime doesn't necessarily guarantee a higher or lower IMDb score.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# * Positive Business Impact:
#
# Since there's no strong correlation, Amazon Prime doesn't need to strictly adhere to a particular runtime to achieve a good IMDb score. This gives them flexibility in acquiring and producing content of varying lengths. They can focus on content quality regardless of runtime, potentially leading to a more diverse library that appeals to different viewer preferences.
#
# * Negative Business Impact:
#
# The lack of correlation also means that simply producing longer or shorter content won't automatically lead to higher ratings. Amazon Prime needs to focus on other factors that influence IMDb scores, such as script quality, acting, directing, etc. If they solely rely on runtime as a factor for content selection or creation, it won't guarantee positive reception and could lead to investing in content that doesn't resonate with viewers, potentially hindering subscriber growth or retention.

# %% [markdown]
# #### Chart - 7: Analyze the relationship between release year and imdb score

# %%
# Chart - 7 visualization code
plt.figure(figsize=(12, 8))
sns.scatterplot(data=titles, x='release_year', y='imdb_score', alpha=0.6)
plt.title('Release Year vs. IMDb Score')
plt.xlabel('Release Year')
plt.ylabel('IMDb Score')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# I picked the scatter plot for Chart 7 to visualize the relationship between release_year and imdb_score because a scatter plot is ideal for showing the relationship between two numerical variables. It allows us to see if there is a trend or correlation between the year a title was released and its IMDb score. By plotting each data point as a dot, we can observe the distribution and identify any patterns or clusters that might suggest a relationship between these two variables over time.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# * There doesn't appear to be a strong linear trend showing a significant increase or decrease in IMDb scores over time. The scores seem to be scattered across the different release years.
# * There's a higher density of titles in recent years (roughly from the late 20th century onwards), which aligns with the overall increase in content production.
# * While most titles fall within the average IMDb score range (around 5 to 8), there are outliers with very high and very low scores across various release years, indicating that quality isn't solely dependent on the release year.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Positive Business Impact:
#
# Flexibility in content acquisition: Since there's no strong correlation between release year and IMDb score, Amazon Prime is not restricted to acquiring only recent titles to ensure high ratings. They can acquire older, critically acclaimed titles that resonate with audiences, diversifying their library and appealing to different viewer preferences.
#
# Negative Growth:
#
# Ignoring trends in viewer preference: While the overall correlation is weak, there might be subtle trends or shifts in viewer preferences over time not immediately obvious from this plot. If Amazon Prime doesn't analyze other factors influencing viewer engagement with content from different eras, they might miss opportunities to cater to evolving tastes or incorrectly assume older content is irrelevant.

# %% [markdown]
# #### Chart - 8: Explore the relationship between imdb votes and imdb score

# %%
# Chart - 8 visualization code
plt.figure(figsize=(12, 8))
sns.scatterplot(data=titles, x='imdb_votes', y='imdb_score', alpha=0.6)
plt.title('IMDb Votes vs. IMDb Score')
plt.xlabel('IMDb Votes')
plt.ylabel('IMDb Score')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
#  By plotting each title as a point with its IMDb vote count on the x-axis and its IMDb score on the y-axis, we can visually inspect if there's a correlation, pattern, or trend between the number of votes a title receives and its average rating. This helps us understand if titles with more votes tend to have higher or lower scores, or if there's no apparent relationship.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# * Concentration of titles with fewer votes: The vast majority of titles are clustered towards the lower end of the IMDb votes axis. This indicates that most titles on Amazon Prime have a relatively small number of IMDb votes.
# * Wider range of scores for titles with fewer votes: Among titles with fewer votes, there seems to be a wider spread of IMDb scores, ranging from very low to very high. This suggests that titles with less audience engagement (fewer votes) can have highly variable ratings.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Positive Business Impact:
#
# Identifying potentially popular and well-regarded content: The insight that titles with more votes tend to have higher scores can help Amazon Prime identify content that is not only popular but also generally well-liked by audiences. This can guide content acquisition decisions, focusing on acquiring titles that have already proven to be popular and well-rated.
#
# Negative Growth:
#
# Over-reliance on existing popularity: While acquiring popular and well-rated content is beneficial, an over-reliance on titles with high vote counts might lead to neglecting newer or less-known content that could also be high-quality but hasn't yet gained traction. This could limit the diversity of the library and potentially miss out on future hits.

# %% [markdown]
# #### Chart - 9: Visualize the top production countries

# %%
# Chart - 9 visualization code
# Process the 'production_countries' column to extract individual country names
countries_list = titles['production_countries'].apply(lambda x: eval(x))
all_countries = [country for sublist in countries_list for country in sublist]

# Count the occurrences of each unique country
country_counts = pd.Series(all_countries).value_counts()

# Select the top 10 most frequent production countries
top_countries = country_counts.head(10)

# Create a bar chart to visualize the counts of these top countries
plt.figure(figsize=(12, 8))
top_countries.plot(kind='bar', color=sns.color_palette('tab10', len(top_countries)))

# Add appropriate labels to the x and y axes and a title to the chart
plt.title('Top 10 Production Countries by Number of Titles')
plt.xlabel('Production Country')
plt.ylabel('Number of Titles')

# Rotate the x-axis labels for better readability
plt.xticks(rotation=45, ha='right')

# Adjust layout to prevent labels overlapping
plt.tight_layout()

# Display the chart
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# the categories are the production countries, and the bar chart clearly shows the number of titles associated with each of the top countries. This allows for easy comparison of the frequency of production across different countries and highlights which countries contribute the most titles to the Amazon Prime library.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# * Dominance of the United States: The United States is by far the most frequent production country for titles on Amazon Prime, with a significantly higher number of titles compared to any other country.
# * Presence of other major film industries: Countries with large and established film industries like India and the United Kingdom are also prominent in the top production countries, albeit with considerably fewer titles than the US.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Positive Business Impact:
#
# Catering to a US audience: The dominance of US-produced content is likely a strong factor in attracting and retaining subscribers in the United States, a major market for Amazon Prime.
# Leveraging established film industries: The presence of content from countries like India and the UK allows Amazon Prime to tap into the audiences and popularity of these major film industries, potentially expanding their subscriber base in those regions or among diaspora communities.
#
# Negative Growth:
#
# Limited appeal in non-dominant regions: The heavy skew towards US content might limit the platform's appeal in countries where local content or content from other non-US regions is more popular. This could hinder subscriber growth in those markets.
# Missing out on emerging markets: If Amazon Prime does not actively seek content from emerging film and television production markets, they might miss out on opportunities to attract new audiences and gain a foothold in those regions.

# %% [markdown]
# #### Chart - 10: Analyze the number of titles released over the years

# %%
# Chart - 10
# Group by release year and count the number of titles
titles_by_year = titles['release_year'].value_counts().sort_index()

# Create a line plot
plt.figure(figsize=(14, 7))
titles_by_year.plot(kind='line', marker='o', linestyle='-')

# Add appropriate labels and title
plt.title('Number of Titles Released Over Time')
plt.xlabel('Release Year')
plt.ylabel('Number of Titles')
plt.grid(True)

# Display the chart
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# I chose a line plot for Chart 10 to visualize the number of titles released over time because a line plot is ideal for showing trends and changes in data over a continuous period, such as years. By plotting the release year on the x-axis and the count of titles on the y-axis, we can clearly see how the volume of content released on Amazon Prime has evolved year by year. The line connects the data points sequentially, making it easy to observe patterns like growth, decline, or stability in the number of releases over the entire history represented in the dataset.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# * Overall Growth: There is a clear upward trend in the number of titles released over the years, especially in the more recent years.
# * Significant Increase in the Last Decade: The plot shows a sharp increase in the number of titles released roughly from the early 2010s onwards, indicating a significant expansion of Amazon Prime's content library in the last decade.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Positive Business Impact:
#
# Library Growth and Subscriber Attraction: The significant increase in the number of titles, especially in recent years, indicates a growing content library. A larger and more diverse library can attract new subscribers with varied interests and provide more options for existing subscribers, potentially leading to higher retention rates.
#
# Negative Growth (if not managed properly):
#
# Content Saturation and Discoverability: While a large library is generally positive, an extremely rapid increase in content could lead to content saturation. Subscribers might find it harder to discover relevant titles, potentially leading to frustration and a feeling of being overwhelmed, which could negatively impact engagement.

# %% [markdown]
# #### Chart - 11: Explore the average imdb score over the years

# %%
# Chart - 11 visualization code
# Group by release year and calculate the mean IMDb score
average_imdb_score_by_year = titles.groupby('release_year')['imdb_score'].mean()

# Create a line plot
plt.figure(figsize=(14, 7))
average_imdb_score_by_year.plot(kind='line', marker='o', linestyle='-')

# Add appropriate labels and title
plt.title('Average IMDb Score Over the Years')
plt.xlabel('Release Year')
plt.ylabel('Average IMDb Score')
plt.grid(True)

# Display the chart
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# I chose a line plot to visualize the average IMDb score over the years because it's the most suitable chart type for showing how a numerical value (average IMDb score) changes over a continuous variable (release year). A line plot clearly illustrates trends, fluctuations, and patterns in the average score over time, making it easy to observe if there's an overall increase, decrease, or stability in the perceived quality of titles based on IMDb ratings as the years progress.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# * Fluctuations in Average Score: The chart shows fluctuations in the average IMDb score across different release years. There isn't a consistent, strong upward or downward trend over the entire period.
# * Potential for Variation in Earlier Years: In the earlier years, the average IMDb score might appear more volatile due to a smaller number of releases in those years.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Positive Business Impact:
#
# Content Quality Consistency: The relatively stable average IMDb score in recent decades suggests that Amazon Prime has been consistently adding content that maintains a certain level of perceived quality, as rated by IMDb users. This consistency can contribute to a reliable viewing experience for subscribers.
#
# Negative Growth (if not managed properly):
#
# No Improvement in Quality Over Time: The lack of a significant upward trend in average IMDb scores over time could be seen as a negative point. While stability is better than decline, it suggests that the overall perceived quality of content, based on this metric, hasn't necessarily improved despite the significant increase in the number of titles released (as seen in Chart 10). This could be a concern if competitors are consistently adding content with higher average ratings.

# %% [markdown]
# #### Chart - 12: Visualize the relationship between tmdb popularity and tmdb score

# %%
# Chart - 12 visualization code
plt.figure(figsize=(12, 8))
sns.scatterplot(data=titles, x='tmdb_popularity', y='tmdb_score', alpha=0.6)
plt.title('TMDB Popularity vs. TMDB Score')
plt.xlabel('TMDB Popularity')
plt.ylabel('TMDB Score')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# I picked the scatter plot to visualize the relationship between tmdb_popularity and tmdb_score because a scatter plot is a suitable chart type for examining the relationship between two continuous numerical variables. It allows us to plot each title as a point based on its TMDB popularity score and its TMDB score. This helps us visually identify if there's a correlation or pattern – for example, if titles with higher popularity tend to have higher scores, or if there's no clear relationship. It allows for the observation of the distribution of data points and potential trends or clusters.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# * Concentration of Low Popularity Titles: Similar to the IMDb votes chart, the vast majority of titles are clustered towards the lower end of the TMDB popularity axis. This indicates that most titles on Amazon Prime have relatively low TMDB popularity scores.
# * Wide Range of Scores for Low Popularity: Among titles with low TMDB popularity, there's a wide spread of TMDB scores, ranging from low to high. This suggests that a low popularity score doesn't necessarily mean a low quality score on TMDB.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Positive Business Impact:
#
# Identifying Potentially Engaging Content: The insight that titles with higher TMDB popularity tend to have higher TMDB scores can help Amazon Prime identify content that is not only well-liked (high score) but also generating significant interest and engagement (high popularity) on TMDB. This can guide content acquisition decisions, focusing on acquiring titles that have already proven to resonate with a broad audience.
#
# Negative Growth:
#
# Over-reliance on Existing Popularity: While acquiring popular content is beneficial, an over-reliance on titles with high TMDB popularity might lead to neglecting newer or less-known content that could also be high-quality but hasn't yet gained traction. This could limit the diversity of the library and potentially miss out on future hits, hindering subscriber growth in niche areas.

# %% [markdown]
# #### Chart - 13: Analyze the top actors and directors

# %%
# Chart - 13 visualization code
# Filter for actors
actors_df = credits[credits['role'] == 'ACTOR']

# Count the occurrences of each actor
actor_counts = actors_df['name'].value_counts()

# Select the top 10 actors
top_10_actors = actor_counts.head(10)

# Filter for directors
directors_df = credits[credits['role'] == 'DIRECTOR']

# Count the occurrences of each director
director_counts = directors_df['name'].value_counts()

# Select the top 10 directors
top_10_directors = director_counts.head(10)

# Create a bar plot for top 10 actors
plt.figure(figsize=(12, 6))
top_10_actors.plot(kind='bar', color=sns.color_palette('viridis', len(top_10_actors)))
plt.title('Top 10 Most Frequent Actors')
plt.xlabel('Actor Name')
plt.ylabel('Number of Titles')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# Create a bar plot for top 10 directors
plt.figure(figsize=(12, 6))
top_10_directors.plot(kind='bar', color=sns.color_palette('magma', len(top_10_directors)))
plt.title('Top 10 Most Frequent Directors')
plt.xlabel('Director Name')
plt.ylabel('Number of Titles')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# I chose bar plots for to visualize the top actors and directors because bar charts are effective for comparing the frequency or count of distinct categories. In this case, the categories are the names of actors and directors, and the bar charts clearly show the number of titles each person has been involved in within the dataset.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# * Prolific Actors: The chart highlights actors who have appeared in a significant number of titles on Amazon Prime. The names on the x-axis represent these actors, and the height of the bars indicates the count of titles they are credited in.
# * Specific Actors' Prevalence: We can identify the specific actors who are most frequently featured. For example, "George 'Gabby' Hayes" and "Roy Rogers" appear to be among the most frequent actors, suggesting a strong presence of older Westerns or serials in the library.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Positive Business Impact:
#
# Identifying Catalog Strengths: Knowing which actors and directors are most represented helps Amazon Prime understand the strengths and characteristics of its content catalog. For example, a high number of titles featuring classic Western actors might indicate a strong collection in that genre, which can be marketed to relevant audiences.
#
# Negative Growth:
#
# Over-reliance on Older Content: If the most frequent actors and directors are predominantly associated with older films or shows, it might indicate a heavy reliance on library content rather than recent or original productions.

# %% [markdown]
# #### Chart - 14 - Correlation Heatmap

# %%
# Correlation Heatmap visualization code
# Calculate the correlation matrix
correlation_matrix = titles.select_dtypes(include=np.number).corr()

# Create a heatmap
plt.figure(figsize=(12, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f")
plt.title('Correlation Heatmap of Numerical Columns')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# I chose a correlation heatmap because it is an excellent visualization tool for displaying the pairwise correlation coefficients between multiple numerical variables in a dataset. It uses color intensity to represent the strength and direction of the correlation (positive or negative), making it easy to quickly identify which variables are strongly correlated, weakly correlated, or not correlated at all.

# %% [markdown]
# 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# * Strong Positive Correlation: There is a strong positive correlation between imdb_score and imdb_votes. This is expected, as titles with higher scores are generally more popular and receive more votes. Similarly, tmdb_popularity and tmdb_score also show a positive correlation.
# * Moderate Positive Correlation: There appears to be a moderate positive correlation between imdb_votes and tmdb_popularity. This suggests that titles popular on IMDb also tend to be popular on TMDB.

# %% [markdown]
# #### Chart - 15 - Pair Plot

# %%
# Pair Plot visualization code
# Select only the numerical columns for the pair plot
numerical_cols = titles.select_dtypes(include=np.number).columns

# Create a pair plot
sns.pairplot(titles[numerical_cols])

# Add a title to the plot (optional, as pairplot doesn't have a built-in title)
plt.suptitle('Pair Plot of Numerical Columns in Titles DataFrame', y=1.02)

# Display the plot
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# I picked the pair plot for Chart 15 because it is a powerful visualization tool that allows us to see both the distribution of individual numerical variables and the pairwise relationships between them in a single plot grid.
#
# For each numerical column in the dataset, the pair plot generates:
#
# * A histogram on the diagonal: This shows the distribution of each individual variable.
# * Scatter plots on the off-diagonal: Each scatter plot shows the relationship between two different numerical variables, allowing us to quickly assess for correlations, patterns, or clusters between every possible pair of numerical columns.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# * Runtime Distribution: The histogram for runtime likely shows a distribution with a peak in the typical movie runtime range (e.g., 70-120 minutes) and another concentration at shorter runtimes (for show episodes), consistent with earlier observations.
# * Release Year Distribution: The histogram for release_year will show the distribution of release years, likely skewed towards more recent years, confirming the growth trend seen previously.
# Score Distributions: The histograms for

# %% [markdown]
# ## **5. Solution to Business Objective**

# %% [markdown]
# #### What do you suggest the client to achieve Business Objective ?
# Explain Briefly.

# %% [markdown]
# Based on the exploratory data analysis, here are some suggestions for the client to achieve their business objectives:
#
# *   **Leverage Content Strengths:** Focus marketing efforts on promoting the types of content that are most prevalent and popular on the platform (e.g., movies, particularly in genres like Drama, Comedy, Action, and Thriller, and content from top production countries like the US, India, and the UK). Highlight the depth of the library in these areas to attract and retain subscribers.
# *   **Address Content Gaps:** Identify areas where the content library might be lacking based on audience demand or competitor offerings (e.g., a relatively smaller number of TV shows compared to movies). Strategically acquire or produce content to fill these gaps and cater to a wider range of viewer preferences.
# *   **Utilize Rating and Popularity Data:** Use IMDb and TMDB scores and popularity metrics to identify high-quality and engaging content for promotion and curation. While not the only factor, these metrics can help in showcasing well-regarded titles to subscribers.
# *   **Consider Content Diversity:** While the US dominates production countries, explore opportunities to include more content from other regions to diversify the library and appeal to international audiences or those interested in global content.
# *   **Analyze Audience Behavior:** Go beyond the current dataset to analyze how subscribers actually engage with different types of content, runtimes, age certifications, and genres. This behavioral data can provide deeper insights into what resonates most with the target audience and inform future content strategy.
# *   **Monitor Trends in Content Quality:** While the average IMDb score has been relatively stable, continuously monitor the quality of newly added content to ensure it meets a certain standard. Invest in producing or acquiring content that has the potential to achieve higher ratings and critical acclaim if elevating the perceived quality of the library is a business objective.
# *   **Improve Content Discoverability:** With the significant increase in the number of titles, focus on improving the content recommendation system and user interface to help subscribers easily find content they are interested in, mitigating the potential negative impact of content saturation.
#
# By strategically using the insights gained from this EDA, Amazon Prime can make more informed decisions about content acquisition, production, marketing, and platform features to attract and retain subscribers, ultimately contributing to achieving their business objectives.

# %% [markdown]
# # **Conclusion**

# %% [markdown]
# Data Analysis Key Findings
# * The dataset contains significantly more movies than shows.
# * The release year distribution shows a sharp increase in titles released in recent years, with a peak around 2020-2022.
# * Movies tend to have a concentrated runtime distribution, while shows have a different distribution related to episode lengths.
# * The most frequent age certification is "TV-MA", followed by "R" and "PG-13".
# * The most frequent genres include Drama, Comedy, Action, and Thriller.
# * IMDb scores are primarily distributed between 6.0 and 8.0, with a peak around 7.0.
# * TMDB scores show a similar distribution to IMDb scores, also peaking around 7.0.
# * Scatter plots show a weak positive relationship between runtime and IMDb score, release year and IMDb score, IMDb votes and IMDb score, and TMDB popularity and TMDB score, with significant scatter in all cases.
# * The United States is the top production country by a large margin, followed by India and the United Kingdom.
# * The number of titles released over the years shows a clear upward trend, especially in the last decade.
# * The average IMDb score over the years fluctuates but doesn't show a strong upward or downward trend.
# * The top 10 most frequent actors and directors are identified and their counts visualized.
# * Average runtime varies across different age certifications, with some certifications having notably higher or lower average runtimes.
# * The distribution of the number of seasons for TV shows indicates that most shows have a small number of seasons, with a sharp decrease as the number of seasons increases.
